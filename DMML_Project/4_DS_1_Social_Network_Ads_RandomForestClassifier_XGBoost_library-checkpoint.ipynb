# %%
# RandomForestClassifier using the XGBoost library
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Load the data
data = pd.read_csv('Social_Network_Ads.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Age              400 non-null    int64
#  1   EstimatedSalary  400 non-null    int64
#  2   Purchased        400 non-null    int64
# dtypes: int64(3)
# memory usage: 9.5 KB

# %%
# Selecting features and target variable

# Assuming 'Age' and 'EstimatedSalary' are the features and 'Purchased' is the target
X = data[['Age', 'EstimatedSalary']].values
y = data['Purchased'].values

# Feature Scaling
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Splitting the dataset into the training set and test set
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.25, random_state=0)

# %%
# !pip install xgboost

# %%
# importing the necessary modules.
import xgboost as xgb
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, f1_score
import matplotlib.pyplot as plt

# %%
# Configure the model to use tree-based learners
model = XGBClassifier(
    n_estimators=100,
    max_depth=5,
    learning_rate=0.1,
    subsample=0.8,
    colsample_bytree=0.8,
    objective='binary:logistic',  # binary classification
    use_label_encoder=False,
    eval_metric='logloss'
)

# Fit model
model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=5,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=100,
#               n_jobs=None, num_parallel_tree=None, random_state=None, ...)

# %%
# Making predictions
y_pred = model.predict(X_test)

# Calculating metrics
accuracy = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print(f'Accuracy: {accuracy:.2f}')
print(f'F1 Score: {f1:.2f}')
# Out:
# Accuracy: 0.93
# F1 Score: 0.89

# %%
# Plotting feature importance
xgb.plot_importance(model)
plt.title('Feature Importance')
plt.show()

# Interpretation:
# Feature f1: This feature has a higher F score (547.0) indicating it is more influential in the model's decisions compared to feature f0. It appears to contribute significantly to the outcome of the model's predictions.
# Feature f0: Although this feature is used in the model, its F score (400.0) is lower compared to f1, suggesting it has a lesser impact on the predictive power of the model.

# %%
# Simple comparison plot
plt.figure(figsize=(10, 5))
plt.scatter(range(len(y_test)), y_test, color='blue', label='Actual', alpha=0.5)
plt.scatter(range(len(y_pred)), y_pred, color='red', label='Predicted', alpha=0.5)
plt.title('Actual vs Predicted')
plt.xlabel('Sample Index')
plt.ylabel('Purchased')
plt.legend()
plt.show()

# %%
# Observations from the Graph:
# High Accuracy: There appears to be a high degree of overlap between the actual and predicted values, suggesting the model is performing well in correctly classifying whether individuals purchased or not based on the features provided to the model.
# Few Misclassifications: The instances where the blue and red dots do not overlap represent misclassifications. For instance, if you see a red dot at 1 (predicted purchase) where there is no blue dot, or a blue dot at 1 where there is a corresponding red dot at 0, those are errors.
